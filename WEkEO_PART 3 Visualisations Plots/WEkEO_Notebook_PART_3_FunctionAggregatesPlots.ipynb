# %% [markdown]
# ### WEkEO Notebook - PART 3: Sea Surface Temperature Plots
# #### Library imports:
# ######     pip install statsmodels
# ######     pip install seaborn
# ##### The "FunctionAggregatesPlots.py" contains the details of the Sea Surface Temperature Analysis.
# ##### Therefore, the plots follow:
# <ol>
# <li>
# Sea Surface Temperature Time Series, Daily Trend in the Adriatic Sea,</li>
#
# <li>
# Sea Surface Temperature Standard Deviation in the Adriatic Sea,</li>
#
# <li>
# Sea Surface Temperature Annual Trend in the Adriatic Sea,</li>
#
# <li>
# Monthly Mean Sea Surface Temperature in the Adriatic Sea.</li>
#
# </ol>

# %%
import xarray as xr
import pandas as pd
from matplotlib import rcParams

import FunctionAggregatesPlots as fap

# %%
ncRawDataFileName1 = "/home/ozlem/WEkEO_Jupyter_Competition/WEkEO_PART_2_Aggregations/WEkEO_SST_DATA/CMEMS_SST_clipped.nc"

# %%
rawData1 = xr.open_dataset(ncRawDataFileName1)

# %%
NcFile1DoutputCSV= "/home/ozlem/WEkEO_Jupyter_Competition/WEkEO_PART_2_Aggregations/WEkEO_SST_DATA/CMEMS_SST_clipped_1D_FIXED_DIM.csv"

# %% [markdown]
# ##### "faGenerateDailyTimeSeries" function in the FunctionAggregatesPlots.py show the Daily Time Series Analysis over interested area

# %%
ts=fap.faGenerateDailyTimeSeries(NcFile1DoutputCSV)

# %% [markdown]
# ##### "faGenerateDailyTimeSeriesSTD" function in the FunctionAggregatesPlots.py show the Standard Deviation over interested area

# %%
ts1=fap.faGenerateDailyTimeSeriesSTD(NcFile1DoutputCSV)

# %% [markdown]
# ##### "faGenerate1DTendency" function in the FunctionAggregatesPlots.py show the Annual Trend over interested area

# %%
NcFile1Doutput = "/home/ozlem/WEkEO_Jupyter_Competition/WEkEO_PART_2_Aggregations/WEkEO_SST_DATA/CMEMS_SST_clipped_1D_FIXED_DIM.nc"
clippedfix1Tendency=fap.faGenerate1DTendency(rawData1,NcFile1Doutput)

# %% [markdown]
# ##### "faGenerateDailyTimeSeriesPLOT" function in the FunctionAggregatesPlots.py show the Annual Trend over interested area

# %%
ts2=fap.faGenerateDailyTimeSeriesPLOT(NcFile1DoutputCSV)
